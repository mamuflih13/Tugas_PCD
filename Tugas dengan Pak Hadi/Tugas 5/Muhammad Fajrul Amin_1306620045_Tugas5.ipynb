# %% [markdown]
# ## Nama    : Muhammad Fajrul Amin
# ## NIM     : 1306620045
# ## Kelas   : Fisika A 2020

# %%
import numpy as np
from PIL import Image, ImageFont, ImageDraw
from PIL.ImageChops import add, subtract, multiply, difference, screen
from skimage.io import imread, imsave, imshow, show, imread_collection, imshow_collection
from skimage import color, viewer, exposure, img_as_float, data
import matplotlib.image as mpimg
import matplotlib.pylab as plt
from scipy.ndimage import affine_transform, zoom
from scipy import misc

# %% [markdown]
# # Gambar awal

# %%
im = Image.open("try1.jpg") # read the image, provide the correct path
plt.imshow(im)
plt.axis('off')
plt.show()

# %% [markdown]
# # Transformasi Rotasi

# %%
im = Image.open("try1.jpg")
im_90 = im.rotate(90) # rotate the image by 45 degrees
plt.imshow(im_90)
plt.axis('off')
plt.show()

# %% [markdown]
# ## Transformasi Affine ##

# %%
im = Image.open("try1.jpg")
im.transform((int(1.4*im.width), im.height), Image.AFFINE,
data=(1,-0.5,0,0,1,0))
# Out:
# <PIL.Image.Image image mode=RGB size=862x1333 at 0x2C8B74F2670>

# %% [markdown]
# ## Perspektif ##

# %%
im = Image.open("try1.jpg")
params = [1, 0.1, 0, -0.1, 0.5, 0, -0.005, -0.001]
im1 = im.transform((im.width//3, im.height), Image.PERSPECTIVE, params,
Image.BICUBIC)
plt.imshow(im1)
plt.axis('off')
plt.show()

# %% [markdown]
# ## Pencerminan ##

# %%
im = Image.open("try1.jpg") 
im.transpose(Image.FLIP_LEFT_RIGHT) # reflect about the vertical axis
# Out:
# <PIL.Image.Image image mode=RGB size=616x1333 at 0x1B2A7D60FA0>

# %% [markdown]
# ## Plot gambar masing-masing nilai RGB ##

# %%
ch_r, ch_g, ch_b = im.split() # split the RGB image into 3 channels: R, G and B
# we shall use matplotlib to display the channels
plt.figure(figsize=(18,6))
plt.subplot(1,3,1); plt.imshow(ch_r, cmap=plt.cm.Reds); plt.axis('off')
plt.subplot(1,3,2); plt.imshow(ch_g, cmap=plt.cm.Greens); plt.axis('off')
plt.subplot(1,3,3); plt.imshow(ch_b, cmap=plt.cm.Blues); plt.axis('off')
plt.tight_layout()
plt.show() # show the R, G, B channels

# %% [markdown]
# ## Histogram RGB Gambaar ##

# %%
im = Image.open("try1.jpg") # read the image, provide the correct path
pl = im.histogram()
plt.bar(range(256), pl[:256], color='r', alpha=0.5)
plt.bar(range(256), pl[256:2*256], color='g', alpha=0.4)
plt.bar(range(256), pl[2*256:], color='b', alpha=0.3)
plt.show()
