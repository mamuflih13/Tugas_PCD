# %% [markdown]
# Nama  : Muhamad Rizki
# NIM   : 1306620051
# Kelas : Fisika 2020
#
# **PENGOLAHAN CITRA DIGITAL**

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np
from PIL import Image
from skimage.color import rgb2gray

# %%
image = Image.open('image.jpg')
plt.imshow(image)

# %% [markdown]
# **Grayscale Image**

# %%
greyscale = rgb2gray(image)
plt.imshow(greyscale, cmap='gray')

# %% [markdown]
# **FFT 1**

# %%
greyscale_fourier = np.fft.fftshift(np.fft.fft2(greyscale))
plt.title('FFT Spectrum')
plt.subplot(121),plt.imshow(np.log(abs(greyscale_fourier)), cmap='gray')
greyscale = rgb2gray(image)
plt.subplot(122),plt.imshow(greyscale, cmap='gray')
# Out:
# (<AxesSubplot:>, <matplotlib.image.AxesImage at 0x201bcec4d00>)

# %% [markdown]
# **FFT 2**

# %%
f = np.fft.fft2(greyscale)
fshift = np.fft.fftshift(f)
magnitude_spectrum = 20*np.log(np.abs(fshift))

plt.subplot(121),plt.imshow(greyscale, cmap = 'gray')
plt.title('Grayscale'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(magnitude_spectrum, cmap = 'gray')
plt.title('FFT Spectrum'), plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# **Phase Spectrum**

# %%
image = cv2.imread('image.jpg')
image = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
dft = np.fft.fft2(image)
dft_shift = np.fft.fftshift(dft)
phase_spectrum = np.angle(dft_shift)

ax1 = plt.subplot(1,2,1)
ax1.imshow(image, cmap='gray')

ax2 = plt.subplot(1,2,2)
ax2.imshow(phase_spectrum, cmap='gray')

plt.subplot(1,2,1), plt.imshow(image, cmap = 'gray')
plt.title('Grayscale'), plt.xticks([]), plt.yticks([])
plt.subplot(1,2,2), plt.imshow(phase_spectrum, cmap = 'gray')
plt.title('Phase Spectrum'), plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# **Invers FFT**

# %%
plt.figure(figsize=(6.4*5, 4.8*5), constrained_layout=False)

img_c2 = np.fft.fft2(img)
img_c3 = np.fft.fftshift(img_c2)
img_c4 = np.fft.ifftshift(img_c3)
img_c5 = np.fft.ifft2(img_c4)

plt.subplot(151), plt.imshow(img, "gray"), plt.title("Grayscale")
plt.subplot(152), plt.imshow(np.log(1+np.abs(img_c2)), "gray"), plt.title("Spectrum")
plt.subplot(153), plt.imshow(np.log(1+np.abs(img_c3)), "gray"), plt.title("Centered Spectrum")
plt.subplot(154), plt.imshow(np.log(1+np.abs(img_c4)), "gray"), plt.title("Decentralized")
plt.subplot(155), plt.imshow(np.abs(img_c5), "gray"), plt.title("Processed Image (Invers FFT)")

plt.show()

# %% [markdown]
# **Threshold**

# %%
thresh = 128
img2 = cv2.threshold(img, thresh, 255, cv2.THRESH_BINARY)[1]
plt.imshow(img2)
