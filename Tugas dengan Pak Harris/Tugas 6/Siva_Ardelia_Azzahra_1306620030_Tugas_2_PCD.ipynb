# %% [markdown]
# **TUGAS 2 PCD**
#
# NAMA  : SIVA ARDELIA AZZAHRA
#
# NIM   : 1306620030
#
# KELAS : 1306620030

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np
from PIL import Image
from skimage.color import rgb2gray

# %% [markdown]
# **Original Image**

# %%
# Showing image
img = cv2.imread('/content/woods-60.jpg')
plt.title('Gambar Original')
plt.imshow(img)

# %% [markdown]
# **Greyscale Image**

# %%
greyscale = rgb2gray(img)
plt.title('Greyscale Image')
plt.imshow(greyscale, cmap='gray')

# %% [markdown]
# **Cara 1: FFT Spectrum**

# %%
greyscale_fourier = np.fft.fftshift(np.fft.fft2(greyscale))
plt.title('FFT Spectrum')
plt.imshow(np.log(abs(greyscale_fourier)), cmap='gray')

# %% [markdown]
# **Cara 2: FFT Spectrum**

# %%
f = np.fft.fft2(greyscale)
fshift = np.fft.fftshift(f)
magnitude_spectrum = 20*np.log(np.abs(fshift))

plt.subplot(121),plt.imshow(greyscale, cmap = 'gray')
plt.title('Greyscale Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(magnitude_spectrum, cmap = 'gray')
plt.title('FFT Spectrum'), plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# **Phase Spectrum**

# %%
img = cv2.imread('/content/woods-60.jpg')
img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
dft = np.fft.fft2(img)
dft_shift = np.fft.fftshift(dft)
phase_spectrum = np.angle(dft_shift)

ax1 = plt.subplot(1,2,1)
ax1.imshow(img, cmap='gray')

ax2 = plt.subplot(1,2,2)
ax2.imshow(phase_spectrum, cmap='gray')

plt.subplot(1,2,1), plt.imshow(img, cmap = 'gray')
plt.title('Greyscale Image'), plt.xticks([]), plt.yticks([])
plt.subplot(1,2,2), plt.imshow(phase_spectrum, cmap = 'gray')
plt.title('Phase Spectrum'), plt.xticks([]), plt.yticks([])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   del sys.path[0]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   from ipykernel import kernelapp as app

# %% [markdown]
# **Invers FFT**

# %%
plt.figure(figsize=(6.4*5, 4.8*5), constrained_layout=False)

img_c2 = np.fft.fft2(img)
img_c3 = np.fft.fftshift(img_c2)
img_c4 = np.fft.ifftshift(img_c3)
img_c5 = np.fft.ifft2(img_c4)

plt.subplot(151), plt.imshow(img, "gray"), plt.title("Greyscale Image")
plt.subplot(152), plt.imshow(np.log(1+np.abs(img_c2)), "gray"), plt.title("Spectrum")
plt.subplot(153), plt.imshow(np.log(1+np.abs(img_c3)), "gray"), plt.title("Centered Spectrum")
plt.subplot(154), plt.imshow(np.log(1+np.abs(img_c4)), "gray"), plt.title("Decentralized")
plt.subplot(155), plt.imshow(np.abs(img_c5), "gray"), plt.title("Processed Image (Invers FFT)")

plt.show()

# %% [markdown]
# **Variasi threshold**

# %%
# Define a threshold, 128 is the middle of black and white in grey scale
thresh = 128
# Threshold the image
img2 = cv2.threshold(img, thresh, 255, cv2.THRESH_BINARY)[1]
# Save image
cv2.imwrite('/content/woods-60.jpg',img2)
plt.imshow(img2)

# %% [markdown]
# **Invers FFT**

# %%
plt.figure(figsize=(6.4*5, 4.8*5), constrained_layout=False)

img_c2 = np.fft.fft2(img)
img_c3 = np.fft.fftshift(img_c2)
img_c4 = np.fft.ifftshift(img_c3)
img_c5 = np.fft.ifft2(img_c4)

plt.subplot(151), plt.imshow(img, "gray"), plt.title("Greyscale Image")
plt.subplot(152), plt.imshow(np.log(1+np.abs(img_c2)), "gray"), plt.title("Spectrum")
plt.subplot(153), plt.imshow(np.log(1+np.abs(img_c3)), "gray"), plt.title("Centered Spectrum")
plt.subplot(154), plt.imshow(np.log(1+np.abs(img_c4)), "gray"), plt.title("Decentralized")
plt.subplot(155), plt.imshow(np.abs(img_c5), "gray"), plt.title("Processed Image (Invers FFT)")

plt.show()
